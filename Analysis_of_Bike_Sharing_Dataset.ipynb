# %% [markdown]
# <a href="https://colab.research.google.com/github/salsabilar311/Proyek-Analisis-Data_Dicoding/blob/main/Analysis_of_Bike_Sharing_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/salsabilar311/Proyek-Analisis-Data_Dicoding/main/day.csv?token=GHSAT0AAAAAACNPNJMRHK5RQIG4RKMM5NWKZNYQH7A'
df = pd.read_csv(url)
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446     331         654
# 1             2  0.363478  0.353739  0.696087   0.248539     131         670
# 2             1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3             1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4             1  0.226957  0.229270  0.436957   0.186900      82        1518
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %% [markdown]
# # Informasi 1

# %% [markdown]
# **Memisahkan dataframe yang memiliki tahun 2011**

# %%
df_1_1 = pd.DataFrame(columns=df.columns)

for i in range(len(df)) :
  if df['yr'][i] == 0 :
    df_1_1 = df_1_1.append(df.loc[i], ignore_index=True)

df_1_1
# Out:
# <ipython-input-117-48b9c5b22b7d>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_1_1 = df_1_1.append(df.loc[i], ignore_index=True)
#     instant      dteday season yr mnth holiday weekday workingday weathersit  \
# 0         1  2011-01-01      1  0    1       0       6          0          2
# 1         2  2011-01-02      1  0    1       0       0          0          2
# 2         3  2011-01-03      1  0    1       0       1          1          1
# 3         4  2011-01-04      1  0    1       0       2          1          1
# 4         5  2011-01-05      1  0    1       0       3          1          1
# ..      ...         ...    ... ..  ...     ...     ...        ...        ...
# 360     361  2011-12-27      1  0   12       0       2          1          2
# 361     362  2011-12-28      1  0   12       0       3          1          1
# 362     363  2011-12-29      1  0   12       0       4          1          1
# 363     364  2011-12-30      1  0   12       0       5          1          1
# 364     365  2011-12-31      1  0   12       0       6          0          1
#
#          temp     atemp       hum  windspeed casual registered   cnt
# 0    0.344167  0.363625  0.805833   0.160446    331        654   985
# 1    0.363478  0.353739  0.696087   0.248539    131        670   801
# 2    0.196364  0.189405  0.437273   0.248309    120       1229  1349
# 3    0.200000  0.212122  0.590435   0.160296    108       1454  1562
# 4    0.226957  0.229270  0.436957   0.186900     82       1518  1600
# ..        ...       ...       ...        ...    ...        ...   ...
# 360  0.325000  0.327633  0.762500   0.188450    103       1059  1162
# 361  0.299130  0.279974  0.503913   0.293961    255       2047  2302
# 362  0.248333  0.263892  0.574167   0.119412    254       2169  2423
# 363  0.311667  0.318812  0.636667   0.134337    491       2508  2999
# 364  0.410000  0.414121  0.615833   0.220154    665       1820  2485
#
# [365 rows x 16 columns]

# %% [markdown]
# **Groupby data dengan season sebagai key**

# %%
df_1_1 = df_1_1.groupby(by='season').cnt.sum()
df_1_1
# Out:
# season
# 1    150000
# 2    347316
# 3    419650
# 4    326137
# Name: cnt, dtype: object

# %% [markdown]
# **Visualisasi data menggunakan bar chart**

# %%
colors = ['lightgreen', 'lightgreen', 'mediumseagreen', 'lightgreen']
plt.figure(figsize=(8, 5))
df_1_1.plot(kind='bar', color=colors)
plt.title('Total Bike Rentals by Season in 2011')
plt.xlabel('Season')
plt.ylabel('Total Bike Rentals')
new_labels = ['Springer', 'Summer', 'Fall', 'Winter']
plt.xticks(range(len(new_labels)), new_labels, rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Memisahkan dataframe yang memiliki tahun 2012**

# %%
df_1_2 = pd.DataFrame(columns=df.columns)

for i in range(len(df)) :
  if df['yr'][i] == 1 :
    df_1_2 = df_1_2.append(df.loc[i], ignore_index=True)

df_1_2
# Out:
# <ipython-input-120-d06dccb4e364>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_1_2 = df_1_2.append(df.loc[i], ignore_index=True)
#     instant      dteday season yr mnth holiday weekday workingday weathersit  \
# 0       366  2012-01-01      1  1    1       0       0          0          1
# 1       367  2012-01-02      1  1    1       1       1          0          1
# 2       368  2012-01-03      1  1    1       0       2          1          1
# 3       369  2012-01-04      1  1    1       0       3          1          2
# 4       370  2012-01-05      1  1    1       0       4          1          1
# ..      ...         ...    ... ..  ...     ...     ...        ...        ...
# 361     727  2012-12-27      1  1   12       0       4          1          2
# 362     728  2012-12-28      1  1   12       0       5          1          2
# 363     729  2012-12-29      1  1   12       0       6          0          2
# 364     730  2012-12-30      1  1   12       0       0          0          1
# 365     731  2012-12-31      1  1   12       0       1          1          2
#
#          temp     atemp       hum  windspeed casual registered   cnt
# 0    0.370000  0.375621  0.692500   0.192167    686       1608  2294
# 1    0.273043  0.252304  0.381304   0.329665    244       1707  1951
# 2    0.150000  0.126275  0.441250   0.365671     89       2147  2236
# 3    0.107500  0.119337  0.414583   0.184700     95       2273  2368
# 4    0.265833  0.278412  0.524167   0.129987    140       3132  3272
# ..        ...       ...       ...        ...    ...        ...   ...
# 361  0.254167  0.226642  0.652917   0.350133    247       1867  2114
# 362  0.253333  0.255046  0.590000   0.155471    644       2451  3095
# 363  0.253333  0.242400  0.752917   0.124383    159       1182  1341
# 364  0.255833  0.231700  0.483333   0.350754    364       1432  1796
# 365  0.215833  0.223487  0.577500   0.154846    439       2290  2729
#
# [366 rows x 16 columns]

# %% [markdown]
# **Groupby data dengan season sebagai key**

# %%
df_1_2 = df_1_2.groupby(by='season').cnt.sum()
df_1_2
# Out:
# season
# 1    321348
# 2    571273
# 3    641479
# 4    515476
# Name: cnt, dtype: object

# %% [markdown]
# **Visualisasi data menggunakan bar chart**

# %%
colors = ['lightpink', 'lightpink', 'crimson', 'lightpink']
plt.figure(figsize=(8, 5))
df_1_1.plot(kind='bar', color=colors)
plt.title('Total Bike Rentals by Season in 2012')
plt.xlabel('Season')
plt.ylabel('Total Bike Rentals')
new_labels = ['Springer', 'Summer', 'Fall', 'Winter']
plt.xticks(range(len(new_labels)), new_labels, rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Informasi 2

# %%
df_2_1 = df.groupby(by='yr').agg({
    "casual": "mean",
    "registered":  "mean"
})
df_2_1
# Out:
#          casual   registered
# yr
# 0    677.402740  2728.358904
# 1   1018.483607  4581.450820

# %%
plt.figure(figsize=(10, 6))
width = 0.40
plt.bar(df_2_1.index-0.2, df_2_1['casual'], width, label='Casual', color='#E69A8D')
plt.bar(df_2_1.index+0.2, df_2_1['registered'], width, label='Registered', color='#5F4B8B')

plt.title('Average Casual and Registered Users per Year')
plt.xlabel('Year')
plt.ylabel('Average User')

new_labels = ['2011', '2012']
plt.xticks(range(len(new_labels)), new_labels, rotation=0)

plt.legend()
plt.xticks(df_2_1.index)
plt.tight_layout()
plt.show()
